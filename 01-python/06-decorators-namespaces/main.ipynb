# %%
2+2
# Out:
# 4

# %% [markdown]
# ### Namespaces:
# A namespace is a same space that hold names (identifiers). Programtically speaking, namespaces are dictionary of identifers (keys) and their objects (values).
#
# 4 types of namespaces:
# 1. Built-in namespace
# 2. Global namespace
# 3. Enclosing namespace
# 4. Local namespace
